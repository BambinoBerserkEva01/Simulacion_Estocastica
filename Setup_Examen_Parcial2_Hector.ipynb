# %% [markdown]
# # 🚀 Setup Rápido - Examen Parcial 2
# **Autor:** Héctor Madera
#
# Este cuaderno prepara todo para tu examen en Colab:
# - Descomprime la toolbox
# - Cambia al directorio correcto
# - Deja el entorno listo para correr `Solucion_Examen_Parcial2_COMPLETA.ipynb`
#
# 👉 Asegúrate de subir los siguientes archivos:
# - `Examen_Parcial2_Hector_COMPLETO.zip`
# - `Muestra 1.csv`
# - `Muestra 2.csv`

# %%
# 🔧 Descomprimir y preparar entorno
import zipfile, os

# Descomprimir el archivo ZIP (debe estar subido en Colab)
zipfile.ZipFile("Examen_Parcial2_Hector_COMPLETO.zip", 'r').extractall("examen")

# Cambiar al directorio toolbox
os.chdir("examen/toolbox")
print("✅ Entorno listo. Ahora sube y abre el archivo Solucion_Examen_Parcial2_COMPLETA.ipynb")
